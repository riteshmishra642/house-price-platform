# %% [markdown]
# # House Price Platform — Exploratory Notebook
#
# This notebook is for **ad-hoc exploration only**. Nothing here should be
# depended on by the production pipeline — all reusable logic lives in
#  and is imported below, not reimplemented in-notebook.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

from src.pipelines.data_ingestion import load_or_create_raw_dataset
from src.preprocessing.cleaning import clean_dataset
from src.feature_engineering.features import engineer_features

raw_df = load_or_create_raw_dataset()
cleaned_df, report = clean_dataset(raw_df)
engineered_df = engineer_features(cleaned_df)
engineered_df.head()

# %%
engineered_df["SalePrice"].describe()
